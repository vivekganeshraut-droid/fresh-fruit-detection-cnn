# %%
import os
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D,BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(os.listdir('/content/drive/MyDrive'))
# Out:
# ['Colab Notebooks', 'IBMDesign20260811-21-l5bxu7.pdf', 'Completion Certificate _ SkillsBuild.pdf', 'Screenshot 2026-08-11 065118.png', 'Google AI Studio', 'fruit data set']

# %%
zip_path="/content/drive/MyDrive/fruit data set"
print(os.listdir(zip_path))
# Out:
# ['archive (2).zip']

# %%
zip_path = "/content/drive/MyDrive/fruit data set/archive (2).zip"

# %%
import zipfile

extract_path = "/content/drive/MyDrive/fruit data set/extracted"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
import os

print(os.listdir(extract_path))
# Out:
# ['Fruit Freshness Dataset', 'README.dataset.txt']

# %%
import os

path = "/content/drive/MyDrive/fruit data set/extracted/Fruit Freshness Dataset"

print(os.listdir(path))
# Out:
# ['Fruit Freshness Dataset']

# %%
path = "/content/drive/MyDrive/fruit data set/extracted/Fruit Freshness Dataset/Fruit Freshness Dataset"

print(os.listdir(path))
# Out:
# ['Apple', 'Banana', 'Strawberry']

# %%
import tensorflow as tf

dataset = tf.keras.utils.image_dataset_from_directory(
    path,
    image_size=(224, 224),
    batch_size=32,
    shuffle=True
)
# Out:
# Found 529 files belonging to 3 classes.

# %%
print(dataset.class_names)
# Out:
# ['Apple', 'Banana', 'Strawberry']

# %%
import os
import shutil

source_path = "/content/drive/MyDrive/fruit data set/extracted/Fruit Freshness Dataset/Fruit Freshness Dataset"

new_path = "/content/fruit_dataset"

fruits = ["Apple", "Banana", "Strawberry"]
conditions = ["Fresh", "Rotten"]

for fruit in fruits:
    for condition in conditions:

        source_folder = os.path.join(source_path, fruit, condition)
        class_name = fruit + "_" + condition
        destination_folder = os.path.join(new_path, class_name)

        os.makedirs(destination_folder, exist_ok=True)

        for file in os.listdir(source_folder):
            source_file = os.path.join(source_folder, file)
            destination_file = os.path.join(destination_folder, file)

            if os.path.isfile(source_file):
                shutil.copy2(source_file, destination_file)

print("Dataset organized successfully!")
# Out:
# Dataset organized successfully!

# %%
print(os.listdir(new_path))
# Out:
# ['Banana_Fresh', 'Banana_Rotten', 'Apple_Fresh', 'Strawberry_Fresh', 'Strawberry_Rotten', 'Apple_Rotten']

# %%
import tensorflow as tf

dataset = tf.keras.utils.image_dataset_from_directory(
    new_path,
    image_size=(224, 224),
    batch_size=32,
    shuffle=True
)

print(dataset.class_names)
# Out:
# Found 529 files belonging to 6 classes.
# ['Apple_Fresh', 'Apple_Rotten', 'Banana_Fresh', 'Banana_Rotten', 'Strawberry_Fresh', 'Strawberry_Rotten']

# %%
import tensorflow as tf

dataset_path = "/content/fruit_dataset"

dataset = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    image_size=(224, 224),
    batch_size=None,      # one image at a time
    shuffle=True,
    seed=42
)

print("Classes:", dataset.class_names)
# Out:
# Found 529 files belonging to 6 classes.
# Classes: ['Apple_Fresh', 'Apple_Rotten', 'Banana_Fresh', 'Banana_Rotten', 'Strawberry_Fresh', 'Strawberry_Rotten']

# %%
total = tf.data.experimental.cardinality(dataset).numpy()

train_size = int(0.70 * total)
val_size = int(0.15 * total)

train_data = dataset.take(train_size)

remaining = dataset.skip(train_size)

validation_data = remaining.take(val_size)

test_data = remaining.skip(val_size)

print("Total:", total)
print("Training:", train_size)
print("Validation:", val_size)
print("Test:", total - train_size - val_size)
# Out:
# Total: 529
# Training: 370
# Validation: 79
# Test: 80

# %%
train_data = train_data.batch(32)
validation_data = validation_data.batch(32)
test_data = test_data.batch(32)

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

train_data = train_data.map(
    lambda x, y: (normalization_layer(x), y)
)

validation_data = validation_data.map(
    lambda x, y: (normalization_layer(x), y)
)

test_data = test_data.map(
    lambda x, y: (normalization_layer(x), y)
)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_data = train_data.prefetch(AUTOTUNE)
validation_data = validation_data.prefetch(AUTOTUNE)
test_data = test_data.prefetch(AUTOTUNE)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

model = models.Sequential([

    # Input
    layers.Input(shape=(224, 224, 3)),

    # First convolution block
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Second convolution block
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Third convolution block
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Convert feature maps to a vector
    layers.Flatten(),

    # Fully connected layer
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),

    # 6 classes
    layers.Dense(6, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ...

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    validation_data=validation_data,
    epochs=15
)
# Out:
# Epoch 1/15
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 17s 761ms/step - accuracy: 0.4081 - loss: 1.7814 - val_accuracy: 0.5443 - val_loss: 1.0602
# Epoch 2/15
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - accuracy: 0.7108 - loss: 0.9069 - val_accuracy: 0.8228 - val_loss: 0.4161
# Epoch 3/15
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.7622 - loss: 0.7502 - val_accuracy: 0.8608 - val_loss: 0.4692
# Epoch 4/15
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 361ms/step - accuracy: 0.8297 - loss: 0.5113 - val_accuracy: 0.8608 - val_loss: 0.3903
# Epoch 5/15
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - accuracy: 0.8378 - loss: 0.4453 - val_accuracy: 0.9747 - val_loss: 0.1348
# Epoch 6/15
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8730 - loss: 0.3506 - val_accuracy: 0.9241 - val_loss: 0.1801
# Epoch 7/15
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.8919 - loss: 0.3175 - val_accuracy: 0.9620 - val_loss: 0.2194
# Epoch 8/15
# ...

# %%
test_loss, test_accuracy = model.evaluate(test_data)

print("Test Accuracy:", test_accuracy)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 545ms/step - accuracy: 0.9875 - loss: 0.0200
# Test Accuracy: 0.987500011920929

# %%
model.save(
    "/content/drive/MyDrive/fruit data set/fruit_freshness_cnn.keras"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
from google.colab import files
from IPython.display import display, clear_output
import ipywidgets as widgets

# Your 6 classes
class_names = [
    'Apple_Fresh',
    'Apple_Rotten',
    'Banana_Fresh',
    'Banana_Rotten',
    'Strawberry_Fresh',
    'Strawberry_Rotten'
]

# Upload button
upload_button = widgets.Button(
    description="📷 Upload Fruit Image",
    button_style="success",
    layout=widgets.Layout(width="250px", height="50px")
)

output = widgets.Output()

def predict_fruit(b):
    with output:
        clear_output()

        uploaded = files.upload()

        if len(uploaded) == 0:
            print("No image selected.")
            return

        image_path = list(uploaded.keys())[0]

        # Load image
        img = load_img(image_path, target_size=(224, 224))

        # Display image
        plt.figure(figsize=(5, 5))
        plt.imshow(img)
        plt.axis("off")
        plt.show()

        # Convert image
        img_array = img_to_array(img)
        img_array = img_array / 255.0
        img_array = np.expand_dims(img_array, axis=0)

        # Prediction
        prediction = model.predict(img_array, verbose=0)

        index = np.argmax(prediction)
        predicted_class = class_names[index]
        confidence = prediction[0][index] * 100

        print("🍎🍌🍓 FRUIT FRESHNESS RESULT")
        print("--------------------------------")
        print("Prediction :", predicted_class)
        print("Confidence :", round(confidence, 2), "%")

upload_button.on_click(predict_fruit)

display(upload_button)
display(output)
# Out:
# Button(button_style='success', description='📷 Upload Fruit Image', layout=Layout(height='50px', width='250px')…
# Output()
